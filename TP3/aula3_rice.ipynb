# %%
from python_files.ImageSegmentation import GetConnectedComponents, Kmeans_Clustering, GetWatershedByImmersion, GetWatershedFromMarks, GPLSegmentation
import matplotlib.pyplot as plt
import cv2 as cv

img_orig = cv.imread("Aula 3 - images/rice.bmp")

# %% [markdown]
# Ex 3

# %%
img = img_orig.copy()
processed = GetConnectedComponents(img)

img[processed == 0] = [255, 0, 0]

plt.subplot(1, 2, 1)
plt.imshow(img)
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(processed, cmap="gray")
plt.axis('off')
plt.show()

# %% [markdown]
# Ex 4

# %%
kmeans_processed = Kmeans_Clustering(img_orig, 3)

plt.subplot(1, 2, 1)
plt.imshow(img_orig)
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(kmeans_processed, cmap="gray")
plt.axis('off')
plt.show()

# %% [markdown]
# Ex 5, 7

# %%
#Ex 5
img_inv = cv.bitwise_not(img_orig)
marks = cv.imread("Aula 3 - images/rice.bmp.mask.bmp")


watterShedImm = GetWatershedByImmersion(img_orig)
watterShedImm_inv = GetWatershedByImmersion(img_inv)

watterShedMark = GetWatershedFromMarks(img_orig, marks)
watterShedMark_inv = GetWatershedFromMarks(img_inv, marks)

watterShedImmOverlap = img_orig.copy()
watterShedImmOverlap[watterShedImm == 0] = [255, 0, 0]

watterShedImmOverlap_inv = img_inv.copy()
watterShedImmOverlap_inv[watterShedImm_inv == 0] = [255, 0, 0]

watterShedMarkOverlap = img_orig.copy()
watterShedMarkOverlap[watterShedMark == 0] = [255, 0, 0]

watterShedMarkOverlap_inv = img_inv.copy()
watterShedMarkOverlap_inv[watterShedMark_inv == 0] = [255, 0, 0]

plt.subplot(1, 2, 1)
plt.imshow(watterShedImmOverlap, cmap="gray")
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(watterShedImmOverlap_inv, cmap="gray")
plt.axis('off')
plt.show()

plt.subplot(1, 2, 1)
plt.imshow(watterShedMarkOverlap, cmap="gray")
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(watterShedMarkOverlap_inv, cmap="gray")
plt.axis('off')
plt.show()

#Ex 7
img_mean = cv.blur(img_orig, (5, 5))

watterShedImm = GetWatershedByImmersion(img_mean)
watterShedMark = GetWatershedFromMarks(img_mean, marks)

watterShedImmOverlap = img_mean.copy()
watterShedImmOverlap[watterShedImm == 0] = [255, 0, 0]

watterShedMarkOverlap = img_mean.copy()
watterShedMarkOverlap[watterShedMark == 0] = [255, 0, 0]

plt.subplot(1, 2, 1)
plt.imshow(watterShedImmOverlap, cmap="gray")
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(watterShedMarkOverlap, cmap="gray")
plt.axis('off')
plt.show()

# %% [markdown]
# Ex 6

# %%
GPLSegmentation(img_orig)
# Out:
# c:\Users\Diogo\Desktop\TAPDI\TAPDI-main\TP3\python_files\ImageSegmentation.py:11: SyntaxWarning: invalid escape sequence '\G'
#   sys.path.append("python_files\GPL_LIB")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 GPLSegmentation(img_orig)
#
# File c:\Users\Diogo\Desktop\TAPDI\TAPDI-main\TP3\python_files\ImageSegmentation.py:84, in GPLSegmentation(image)
#      82 buffer = my_instance.Get_OutputImage()
#      83 imgOut = np.frombuffer(buffer, dtype=np.uint8)
# ---> 84 deserialized_x = np.reshape(imgOut, newshape=(image.shape[0],image.shape[1]))
#      85 return deserialized_x
#
# File c:\Users\Diogo\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\_core\fromnumeric.py:328, in reshape(a, shape, order, newshape, copy)
#     326 if copy is not None:
#     327     return _wrapfunc(a, 'reshape', shape, order=order, copy=copy)
# ...

# %% [markdown]
# Ex 8

# %%
imgGray = cv.imread("Aula 3 - images/circles2.png", 0)

imgDT = cv.distanceTransform(imgGray, distanceType=cv.DIST_L2, maskSize=3)

imgDT = cv.cvtColor(imgDT, cv.COLOR_GRAY2RGB)

#watterShedImmGray = GetWatershedByImmersion(imgDT)

#watterShedImmOverlapGray = imgGray.copy()
#watterShedImmOverlapGray[watterShedImmGray == 0] = [255, 0, 0]

plt.subplot(1, 2, 1)
plt.imshow(imgGray, cmap="gray")
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(imgDT, cmap="gray")
plt.axis('off')
plt.show()

""" plt.subplot(1, 2, 1)
plt.imshow(watterShedImmGray, cmap="gray")
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(imgDT, cmap="gray")
plt.axis('off')
plt.show() """
# Out:
# ' plt.subplot(1, 2, 1)\nplt.imshow(watterShedImmGray, cmap="gray")\nplt.axis(\'off\')\nplt.subplot(1, 2, 2)\nplt.imshow(imgDT, cmap="gray")\nplt.axis(\'off\')\nplt.show() '

# %%
imgGray = cv.imread("Aula 3 - images/rice_non_uniform.bmp", 0)

imgDT = cv.distanceTransform(imgGray, distanceType=cv.DIST_L2, maskSize=3)

imgDT = cv.cvtColor(imgDT, cv.COLOR_GRAY2RGB)

watterShedImmGray = GetWatershedByImmersion(imgDT)

#watterShedImmOverlapGray = imgGray.copy()
#watterShedImmOverlapGray[watterShedImmGray == 0] = [255, 0, 0]

plt.subplot(1, 2, 1)
plt.imshow(imgGray, cmap="gray")
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(imgDT, cmap="gray")
plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [3.4028235e+38..3.4028235e+38].
